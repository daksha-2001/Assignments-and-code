# %%
import pandas as pd
df1=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
df2=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt",sep=" ")
df3=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")
df4=pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")

# %%
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df2
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df2
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df3
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df4
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df1.shape

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=55, step=1)

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=1714, step=1)

# %%
c=df1.groupby("item_name")
c=c.sum()
c=c.sort_values(['quantity'],ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# Most costly beer

# %%
c=df2.groupby('name').sum()
c=c.sort_values(['cost'],ascending=False)
c.head(1)
# Out:
#        calories  sodium  alcohol  cost
# name
# Kirin       149       6      5.0  0.79

# %%
Max murder rate

# %%
c=df3.groupby('Year').sum()
c=c.sort_values(['Murder'],ascending=False)
c.head(1)
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1991   252177000  14872900  1911770  12961100   24700         106590   687730
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1991             1092740   3157200        8142200        1661700

# %% [markdown]
# Package having max rows

# %%
c=df4.groupby('Package').sum()
c=c.sort_values(['Rows'],ascending=False)
c.head(1)
# Out:
#               Rows  Cols  n_binary  n_character  n_factor  n_logical  \
# Package
# openintro  2093481  1429       283          156       346         17
#
#            n_numeric
# Package
# openintro        898

# %% [markdown]
# Replacing dollar sign and calculating the revenue

# %%
df1['item_price']=df1['item_price'].replace("$",'')
c=(df1['quantity']*df1['item_price']).sum()
print("Revenue",c)
# Out:
# Revenue 39237.02

# %% [markdown]
# displaying max price and creating a new column displaying revenue of each item

# %%
df1[df1['item_price']==max(df1['item_price'])]
fil=df1.drop_duplicates(['item_name'])

fil['Revenue']=(fil['quantity']*fil['item_price'])
fil
# Out:
# C:\Users\daksh\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# ...

# %% [markdown]
# Sodium-alcohol

# %%
df2['Sodium-alcohol']=df2['sodium']*df2['alcohol']

# %%
df2
# Out:
#                     name  calories  sodium  alcohol  cost  Sodium-alcohol
# 0              Budweiser       144      15      4.7  0.43            70.5
# 1                Schlitz       151      19      4.9  0.43            93.1
# 2              Lowenbrau       157      15      0.9  0.48            13.5
# 3            Kronenbourg       170       7      5.2  0.73            36.4
# 4               Heineken       152      11      5.0  0.77            55.0
# 5          Old_Milwaukee       145      23      4.6  0.28           105.8
# 6             Augsberger       175      24      5.5  0.40           132.0
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42           126.9
# 8            Miller_Lite        99      10      4.3  0.43            43.0
# 9        Budweiser_Light       113       8      3.7  0.40            29.6
# 10                 Coors       140      18      4.6  0.44            82.8
# 11           Coors_Light       102      15      4.1  0.46            61.5
# ...

# %% [markdown]
# Max Burglary

# %%
df3[df3['Burglary']==max(df3['Burglary'])]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 20  1980   225349264  13408300  1344520  12063700   23040          82990
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 20   565840              672650   3795200        7136900        1131700

# %%
filtered=df1.drop_duplicates(['item_name','quantity'])

# %%
del df1['Revenue']

# %%
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df1.sort_values(['item_price'],ascending=True)
# Out:
#       order_id  quantity                     item_name  \
# 1140       471         1                 Bottled Water
# 821        338         1                   Canned Soda
# 3926      1575         1                   Canned Soda
# 107         47         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# ...        ...       ...                           ...
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 1254       511         4               Chicken Burrito
# 3480      1398         3                 Carnitas Bowl
# 3598      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description  item_price
# 1140                                                NaN        1.09
# 821                                         [Coca Cola]        1.09
# 3926                                       [Dr. Pepper]        1.09
# ...

# %% [markdown]
# sorting values of other datasets

# %%
df4.sort_values(['Cols'],ascending=True)
# Out:
#          Package                   Item  \
# 57           AER        MSCISwitzerland
# 129         boot                 darwin
# 1011  mosaicData                  Cards
# 128         boot                   coal
# 232   causaldata  gov_transfers_density
# ...          ...                    ...
# 718          gap                  crohn
# 383         DAAG                rockArt
# 1020  mosaicData               HELPfull
# 1258        plyr                  ozone
# 859         ISLR                  NCI60
#
#                                                   Title   Rows  Cols  \
# 57                               MSCI Switzerland Index   4697     1
# 129                   Darwin's Plant Height Differences     15     1
# 1011                             Standard Deck of Cards     52     1
# 128                      Dates of Coal Mining Disasters    191     1
# 232   Data from "Government Transfers and Political ...  52549     1
# ...

# %%
df2.sort_values(['cost'],ascending=True)
# Out:
#                     name  calories  sodium  alcohol  cost  Sodium-alcohol
# 5          Old_Milwaukee       145      23      4.6  0.28           105.8
# 15     Pabst_Extra_Light        68      15      2.3  0.38            34.5
# 9        Budweiser_Light       113       8      3.7  0.40            29.6
# 6             Augsberger       175      24      5.5  0.40           132.0
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42           126.9
# 17   Heilemans_Old_Style       144      24      4.9  0.43           117.6
# 16                 Hamms       139      19      4.4  0.43            83.6
# 8            Miller_Lite        99      10      4.3  0.43            43.0
# 0              Budweiser       144      15      4.7  0.43            70.5
# 1                Schlitz       151      19      4.9  0.43            93.1
# 10                 Coors       140      18      4.6  0.44            82.8
# 18   Olympia_Goled_Light        72       6      2.9  0.46            17.4
# ...

# %%
df3.sort_values(['Robbery'],ascending=True)
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# ...

# %% [markdown]
# Cost column describe by sodium column

# %%
df2.groupby('sodium').cost.describe()
# Out:
#         count    mean       std   min     25%    50%     75%   max
# sodium
# 6         2.0  0.6250  0.233345  0.46  0.5425  0.625  0.7075  0.79
# 7         2.0  0.6000  0.183848  0.47  0.5350  0.600  0.6650  0.73
# 8         1.0  0.4000       NaN  0.40  0.4000  0.400  0.4000  0.40
# 10        1.0  0.4300       NaN  0.43  0.4300  0.430  0.4300  0.43
# 11        2.0  0.6350  0.190919  0.50  0.5675  0.635  0.7025  0.77
# 15        4.0  0.4375  0.043493  0.38  0.4175  0.445  0.4650  0.48
# 18        1.0  0.4400       NaN  0.44  0.4400  0.440  0.4400  0.44
# 19        3.0  0.5400  0.190526  0.43  0.4300  0.430  0.5950  0.76
# 23        1.0  0.2800       NaN  0.28  0.2800  0.280  0.2800  0.28
# 24        2.0  0.4150  0.021213  0.40  0.4075  0.415  0.4225  0.43
# 27        1.0  0.4200       NaN  0.42  0.4200  0.420  0.4200  0.42

# %%
df4.groupby('CSV').Cols.describe()
# Out:
#                                                     count  mean  std  min  \
# CSV
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   9.0  NaN  9.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   2.0  NaN  2.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   4.0  NaN  4.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   5.0  NaN  5.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   2.0  NaN  2.0
# ...                                                   ...   ...  ...  ...
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   3.0  NaN  3.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   4.0  NaN  4.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   4.0  NaN  4.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   2.0  NaN  2.0
# https://vincentarelbundock.github.io/Rdatasets/...    1.0   2.0  NaN  2.0
#
#                                                     25%  50%  75%  max
# ...

# %% [markdown]
# Set Year column as index

# %%
df3=df3.set_index('Year',drop=True)
df3.head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960              154320    912100        1855400         328200
# 1961              156760    949600        1913000         336000
# 1962              164570    994300        2089600         366800
# 1963              174210   1086400        2297800         408300
# 1964              203050   1213200        2514400         472800

# %% [markdown]
# Return first 3 rows of dataset 4

# %%
df4.iloc[:5]
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %% [markdown]
# Selecting specific columns

# %%
df3.iloc[:,1:4].head()
# Out:
#         Total  Violent  Property
# Year
# 1960  3384200   288460   3095700
# 1961  3488000   289390   3198600
# 1962  3752200   301510   3450700
# 1963  4109500   316970   3792500
# 1964  4564600   364220   4200400

# %%
df2.loc[df2.index[[3, 4, 8]], ['name', 'sodium']]
# Out:
#           name  sodium
# 3  Kronenbourg       7
# 4     Heineken      11
# 8  Miller_Lite      10

# %%
df3
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175   3384200   288460   3095700    9110          17190   107840
# 1961   182992000   3488000   289390   3198600    8740          17220   106670
# 1962   185771000   3752200   301510   3450700    8530          17550   110860
# 1963   188483000   4109500   316970   3792500    8640          17650   116470
# 1964   191141000   4564600   364220   4200400    9360          21420   130390
# 1965   193526000   4739400   387390   4352000    9960          23410   138690
# 1966   195576000   5223500   430180   4793300   11040          25820   157990
# 1967   197457000   5903400   499930   5403500   12240          27620   202910
# 1968   199399000   6720200   595010   6125200   13800          31670   262840
# 1969   201385000   7410900   661870   6749000   14760          37170   298850
# 1970   203235298   8098000   738820   7359200   16000          37990   349860
# ...

# %%
df3[df3['Population'].between(200000000,300000000)]
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1969   201385000   7410900   661870   6749000   14760          37170   298850
# 1970   203235298   8098000   738820   7359200   16000          37990   349860
# 1971   206212000   8588200   816500   7771700   17780          42260   387700
# 1972   208230000   8248800   834900   7413900   18670          46850   376290
# 1973   209851000   8718100   875910   7842200   19640          51400   384220
# 1974   211392000  10253400   974720   9278700   20710          55400   442400
# 1975   213124000  11292400  1039710  10252700   20510          56090   470500
# 1976   214659000  11349700  1004210  10345500   18780          57080   427810
# 1977   216332000  10984500  1029580   9955000   19120          63500   412610
# 1978   218059000  11209000  1085550  10123400   19560          67610   426930
# 1979   220099000  12249500  1208030  11041500   21460          76390   480700
# ...

# %%
df2.groupby('calories')['cost'].mean()
# Out:
# calories
# 68     0.380
# 72     0.460
# 97     0.470
# 99     0.430
# 102    0.460
# 113    0.400
# 135    0.500
# 139    0.430
# 140    0.440
# 144    0.430
# 145    0.280
# 149    0.605
# 150    0.760
# 151    0.430
# 152    0.770
# 157    0.480
# 170    0.730
# 175    0.400
# Name: cost, dtype: float64

# %% [markdown]
# Sort df first by the values in the 'Murder' in decending order, then by the value in the 'Violent' column in ascending order.

# %%
Mur=df3.sort_values(['Murder'],ascending=True)
Mur.sort_values(['Forcible_Rape'],ascending=False)
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1992   255082000  14438200  1932270  12505900   23760         109060   672480
# 1991   252177000  14872900  1911770  12961100   24700         106590   687730
# 1993   257908000  14144800  1926020  12218800   24530         106010   659870
# 1990   248709873  14475600  1820130  12655500   23440         102560   639270
# 1994   260341000  13989500  1857670  12131900   23330         102220   618950
# 1995   262755000  13862700  1798790  12063900   21610          97470   580510
# 1996   265228572  13493863  1688540  11805300   19650          96250   535590
# 1997   267637000  13194571  1634770  11558175   18208          96153   498534
# 2002   287973924  11878954  1423677  10455277   16229          95235   420806
# 2004   293656842  11679474  1360088  10319386   16148          95089   401470
# 1989   248239000  14251400  1646040  12605400   21500          94500   578330
# ...

# %%
Mur
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1962   185771000   3752200   301510   3450700    8530          17550   110860
# 1963   188483000   4109500   316970   3792500    8640          17650   116470
# 1961   182992000   3488000   289390   3198600    8740          17220   106670
# 1960   179323175   3384200   288460   3095700    9110          17190   107840
# 1964   191141000   4564600   364220   4200400    9360          21420   130390
# 1965   193526000   4739400   387390   4352000    9960          23410   138690
# 1966   195576000   5223500   430180   4793300   11040          25820   157990
# 1967   197457000   5903400   499930   5403500   12240          27620   202910
# 1968   199399000   6720200   595010   6125200   13800          31670   262840
# 2014   318857056   9475816  1197987   8277829   14249          84041   325802
# 2013   316497531   9850445  1199684   8650761   14319          82109   345095
# ...

# %% [markdown]
# For each cyl type and each number of gears, find the mean mileage.

# %%
df2.pivot_table(index='cost', columns='name', values='calories', aggfunc='mean')
# Out:
# name  Augsberger  Becks  Budweiser  Budweiser_Light  Coors  Coors_Light  \
# cost
# 0.28         NaN    NaN        NaN              NaN    NaN          NaN
# 0.38         NaN    NaN        NaN              NaN    NaN          NaN
# 0.40       175.0    NaN        NaN            113.0    NaN          NaN
# 0.42         NaN    NaN        NaN              NaN    NaN          NaN
# 0.43         NaN    NaN      144.0              NaN    NaN          NaN
# 0.44         NaN    NaN        NaN              NaN  140.0          NaN
# 0.46         NaN    NaN        NaN              NaN    NaN        102.0
# 0.47         NaN    NaN        NaN              NaN    NaN          NaN
# 0.48         NaN    NaN        NaN              NaN    NaN          NaN
# 0.50         NaN    NaN        NaN              NaN    NaN          NaN
# 0.73         NaN    NaN        NaN              NaN    NaN          NaN
# 0.76         NaN  150.0        NaN              NaN    NaN          NaN
# ...
